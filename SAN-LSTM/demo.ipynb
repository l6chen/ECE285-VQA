# %%
# %pylab inline

import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load your test image here

# %%
img_path = "Data/val2015/abstract_v002_val2015_000000022221.png"
img_pre = mpimg.imread(img_path)
plt.imshow(img_pre)
plt.show()
# pylab.show()

# %% [markdown]
# # Ask your question here

# %%
ques = input()
# Out:
# sdfs

# %% [markdown]
# # Run the following cell to get answers

# %%
run predict.py \
--model_path="Data/Models/model43.ckpt"
--image_path=img_path \
--question=ques
# Out:
# INFO:tensorflow:Restoring parameters from Data/Models/model199.ckpt
# Image: Data/val2015/abstract_v002_val2015_000000022222.png
# Question: Who is lying on the carpet?
# Ans: girl
# Top Answers
# girl
# boy
# no one
# man
# dog
