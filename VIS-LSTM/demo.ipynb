# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import pylab
import evaluate as eva

# %%
img_path = "Data/val2015/abstract_v002_val2015_000000021212.png"
img_pre = mpimg.imread(img_path)
plt.imshow(img_pre)
plt.show()

# %%
ques = "Where is the cat?"

# %%
# %run predict.py --image_path="Data/val2015/abstract_v002_val2015_000000021212.png" \
--question="Where is the cat?" --model_path="Data/Models/model49.ckpt"
# Out:
# INFO:tensorflow:Restoring parameters from Data/Models_best/model49.ckpt
# Image: Data/val2015/abstract_v002_val2015_000000021212.png
# Question: Where is the cat?
# Ans: rug
# Top Answers
# rug
# stool
# chair
# couch
# floor
